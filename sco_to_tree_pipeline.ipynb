# %%
from glob import glob
import os
from collections import defaultdict

def get_organism(gff):
    genome_dir = os.path.dirname(gff)
    report = glob(f'{genome_dir}/*.gbff')
    
    with open(report[0]) as fh:
        for line in fh:
            if line.startswith('SOURCE'):
                organism = line.split('SOURCE')[-1].strip()
    return organism

def get_pid(gff, protein_name):
    with open(gff) as fh:
        for line in fh:
            if protein_name.lower() in line.lower():
                pid = line.split("\t")[8].split("Name=")[-1].split(";")[0]
                return pid
                
def fasta_read(path_to_fasta_file):
    "Returns dictionary header:sequence"
    fasta = {}
    header = None
    with open(path_to_fasta_file) as fh:
        for i, line in enumerate(fh):
            line = line.strip()
            if line.startswith(">"):
                if header:
                    fasta[header] = "".join(seq)
                header = line[1:].split()[0]
                seq = []
            else:
                seq.append(line)
        if header:
            fasta[header] = "".join(seq)
    return fasta

# %%
sco_to_analize = ['30S ribosomal protein S7',
                  'molecular chaperone DnaK',
                  'F0F1 ATP synthase subunit alpha',
                  '50S ribosomal protein L6',
                  'aminoacyl-tRNA hydrolase',
                  'nucleotide exchange factor GrpE',
                  'uracil phosphoribosyltransferase',
                  'translation initiation factor IF-1',
                  '30S ribosome-binding factor RbfA',
                  'preprotein translocase subunit SecG',
                  'amidotransferase subunit GatB',
                  'cell wall cluster transcriptional repressor MraZ',
                  'deoxyribose-phosphate aldolase',
                  'methyltransferase RsmH',
                  '50S ribosomal protein L32',
                 'chromosomal replication initiator protein DnaA']

## sco num_bact n_missed uniq_prots prots_in_multifasta multifasta_file
summary_table = []

anno_files = glob("/home/dzilov/data_zilov/data/mycoplasma/*/*/*.gff")

print(len(anno_files), 'genomes to analyze')


# read all cds fastas
all_fastas = []
for i in glob("/home/dzilov/data_zilov/data/mycoplasma/*/*/*cds_from_genomic.fna"):
    fasta = fasta_read(i)
    all_fastas.append(fasta)
    
# build multifasta for each sco by all bacteria

for sco in sco_to_analize:
    print(f"take {sco} to build multifasta")
    
    sco_joined = "_".join(sco.split())
    multifasta_file = f"/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/{sco_joined}.fasta"
    
#     if os.path.exists(multifasta_file) and os.path.getsize(multifasta_file) != 0:
#         print(f"Multifasta for {sco} already written, continue...")
#         continue
    
    
    pids2bact = {} 
    n_missed = 0
    for file in anno_files:
        prot2bact = [get_pid(file, sco), get_organism(file)]
        if prot2bact[0] and prot2bact[1]:
            pids2bact[prot2bact[0]] = prot2bact[1]
        else:
            n_missed += 1
            print(f"MISSED {sco} in {file}, organism: {prot2bact[1]}")
    
    print(f'{len(pids2bact)} uniq prots in {sco}')
        
    multifasta = {}
    for pid, organism in pids2bact.items():
        for prots in all_fastas:
            for header, seq in prots.items():
                if pid in header:
                    short_organism = "_".join(organism.split(",")[0].split())
                    multifasta[f"{pid}_{short_organism}"]=seq
    
    

    with open(multifasta_file, "w") as fw:
        for h, s in multifasta.items():
            fw.write(f">{h}\n{s}\n")
            
    print(len(multifasta.keys()), f'prots added to multifasta {multifasta_file}')
    
    sco_summary = [sco, str(len(all_fastas)), str(n_missed), str(len(pids2bact)), multifasta_file]
    summary_table.append(sco_summary)
# Out:
# MISSED 30S ribosome-binding factor RbfA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000008405.1_ASM840v1/GCF_000008405.1_ASM840v1_genomic.gff, organism: Mycoplasma hyopneumoniae 232
# MISSED 30S ribosome-binding factor RbfA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000281235.1_ASM28123v1/GCF_000281235.1_ASM28123v1_genomic.gff, organism: Candidatus Mycoplasma haemolamae str. Purdue
# MISSED 30S ribosome-binding factor RbfA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000477415.1_ASM47741v1/GCF_000477415.1_ASM47741v1_genomic.gff, organism: Mycoplasma parvum str. Indiana
# MISSED 30S ribosome-binding factor RbfA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_021383865.1_ASM2138386v1/GCF_021383865.1_ASM2138386v1_genomic.gff, organism: Mycoplasma hyopneumoniae
# MISSED 30S ribosome-binding factor RbfA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000400855.1_ASM40085v1/GCF_000400855.1_ASM40085v1_genomic.gff, organism: Mycoplasma hyopneumoniae 168-L
# MISSED 30S ribosome-binding factor RbfA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000183185.1_ASM18318v1/GCF_000183185.1_ASM18318v1_genomic.gff, organism: Mycoplasma hyopneumoniae 168
# 74 uniq prots in 30S ribosome-binding factor RbfA
# 74 prots added to multifasta /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/30S_ribosome-binding_factor_RbfA.fasta
# take preprotein translocase subunit SecG to build multifasta
# MISSED preprotein translocase subunit SecG in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000009045.1/genomic.gff, organism: Bacillus subtilis subsp. subtilis str. 168
# MISSED preprotein translocase subunit SecG in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_003697165.1/genomic.gff, organism: Escherichia coli DSM 30083 = JCM 1649 = ATCC 11775
# MISSED preprotein translocase subunit SecG in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000179035.2_ASM17903v2/GCF_000179035.2_ASM17903v2_genomic.gff, organism: Mycoplasma suis str. Illinois
# MISSED preprotein translocase subunit SecG in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000203215.1_ASM20321v1/GCF_000203215.1_ASM20321v1_genomic.gff, organism: Mycoplasma suis KI3806
# MISSED preprotein translocase subunit SecG in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000281235.1_ASM28123v1/GCF_000281235.1_ASM28123v1_genomic.gff, organism: Candidatus Mycoplasma haemolamae str. Purdue
# MISSED preprotein translocase subunit SecG in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000477415.1_ASM47741v1/GCF_000477415.1_ASM47741v1_genomic.gff, organism: Mycoplasma parvum str. Indiana
# 75 uniq prots in preprotein translocase subunit SecG
# 75 prots added to multifasta /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/preprotein_translocase_subunit_SecG.fasta
# take amidotransferase subunit GatB to build multifasta
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000013425.1/genomic.gff, organism: Staphylococcus aureus subsp. aureus NCTC 8325
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000009045.1/genomic.gff, organism: Bacillus subtilis subsp. subtilis str. 168
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_007632255.1/genomic.gff, organism: Klebsiella aerogenes
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000006945.2/genomic.gff, organism: Salmonella enterica subsp. enterica serovar Typhimurium str. LT2
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000013285.1/genomic.gff, organism: Clostridium perfringens ATCC 13124
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_016864475.1/genomic.gff, organism: Escherichia coli ATCC 8739
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_003697165.1/genomic.gff, organism: Escherichia coli DSM 30083 = JCM 1649 = ATCC 11775
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000277795.1_ASM27779v1/GCF_000277795.1_ASM27779v1_genomic.gff, organism: Mycoplasma wenyonii str. Massachusetts
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000179035.2_ASM17903v2/GCF_000179035.2_ASM17903v2_genomic.gff, organism: Mycoplasma suis str. Illinois
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000018785.1_ASM1878v1/GCF_000018785.1_ASM1878v1_genomic.gff, organism: Acholeplasma laidlawii PG-8A
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_900476025.1_50465_E02/GCF_900476025.1_50465_E02_genomic.gff, organism: Acholeplasma laidlawii
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000203215.1_ASM20321v1/GCF_000203215.1_ASM20321v1_genomic.gff, organism: Mycoplasma suis KI3806
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_900660755.1_57792_F01-3/GCF_900660755.1_57792_F01-3_genomic.gff, organism: Acholeplasma hippikon
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000281235.1_ASM28123v1/GCF_000281235.1_ASM28123v1_genomic.gff, organism: Candidatus Mycoplasma haemolamae str. Purdue
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000477415.1_ASM47741v1/GCF_000477415.1_ASM47741v1_genomic.gff, organism: Mycoplasma parvum str. Indiana
# MISSED amidotransferase subunit GatB in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000508245.1_ASM50824v1/GCF_000508245.1_ASM50824v1_genomic.gff, organism: Mycoplasma ovis str. Michigan
# 103 uniq prots in amidotransferase subunit GatB
# 102 prots added to multifasta /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/amidotransferase_subunit_GatB.fasta
# take cell wall cluster transcriptional repressor MraZ to build multifasta
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000013425.1/genomic.gff, organism: Staphylococcus aureus subsp. aureus NCTC 8325
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_001552035.1/genomic.gff, organism: Streptococcus agalactiae
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_017569245.1/genomic.gff, organism: Streptococcus pneumoniae
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000009045.1/genomic.gff, organism: Bacillus subtilis subsp. subtilis str. 168
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_001267845.1/genomic.gff, organism: Streptococcus pyogenes
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000013285.1/genomic.gff, organism: Clostridium perfringens ATCC 13124
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_018309165.1/genomic.gff, organism: Bacillus cereus
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000277795.1_ASM27779v1/GCF_000277795.1_ASM27779v1_genomic.gff, organism: Mycoplasma wenyonii str. Massachusetts
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000179035.2_ASM17903v2/GCF_000179035.2_ASM17903v2_genomic.gff, organism: Mycoplasma suis str. Illinois
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000200735.1_ASM20073v1/GCF_000200735.1_ASM20073v1_genomic.gff, organism: Mycoplasma haemofelis str. Langford 1
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000018785.1_ASM1878v1/GCF_000018785.1_ASM1878v1_genomic.gff, organism: Acholeplasma laidlawii PG-8A
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000183365.1_ASM18336v1/GCF_000183365.1_ASM18336v1_genomic.gff, organism: Mycoplasma leachii PG50
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_900476025.1_50465_E02/GCF_900476025.1_50465_E02_genomic.gff, organism: Acholeplasma laidlawii
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000203215.1_ASM20321v1/GCF_000203215.1_ASM20321v1_genomic.gff, organism: Mycoplasma suis KI3806
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_900660755.1_57792_F01-3/GCF_900660755.1_57792_F01-3_genomic.gff, organism: Acholeplasma hippikon
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_001484045.1_ASM148404v1/GCF_001484045.1_ASM148404v1_genomic.gff, organism: Mycoplasma sp. (ex Biomphalaria glabrata)
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000238995.1_ASM23899v1/GCF_000238995.1_ASM23899v1_genomic.gff, organism: Mycoplasma haemocanis str. Illinois
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000875755.1_ASM87575v1/GCF_000875755.1_ASM87575v1_genomic.gff, organism: Mycoplasma yeatsii GM274B
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000281235.1_ASM28123v1/GCF_000281235.1_ASM28123v1_genomic.gff, organism: Candidatus Mycoplasma haemolamae str. Purdue
# MISSED cell wall cluster transcriptional repressor MraZ in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000508245.1_ASM50824v1/GCF_000508245.1_ASM50824v1_genomic.gff, organism: Mycoplasma ovis str. Michigan
# 69 uniq prots in cell wall cluster transcriptional repressor MraZ
# 69 prots added to multifasta /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/cell_wall_cluster_transcriptional_repressor_MraZ.fasta
# take deoxyribose-phosphate aldolase to build multifasta
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000013425.1/genomic.gff, organism: Staphylococcus aureus subsp. aureus NCTC 8325
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_001045685.1/genomic.gff, organism: Pseudomonas aeruginosa DSM 50071 = NBRC 12689
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_001953135.1/genomic.gff, organism: Lactobacillus delbrueckii subsp. bulgaricus
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000006945.2/genomic.gff, organism: Salmonella enterica subsp. enterica serovar Typhimurium str. LT2
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_003697165.1/genomic.gff, organism: Escherichia coli DSM 30083 = JCM 1649 = ATCC 11775
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000277795.1_ASM27779v1/GCF_000277795.1_ASM27779v1_genomic.gff, organism: Mycoplasma wenyonii str. Massachusetts
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000179035.2_ASM17903v2/GCF_000179035.2_ASM17903v2_genomic.gff, organism: Mycoplasma suis str. Illinois
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000200735.1_ASM20073v1/GCF_000200735.1_ASM20073v1_genomic.gff, organism: Mycoplasma haemofelis str. Langford 1
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000203215.1_ASM20321v1/GCF_000203215.1_ASM20321v1_genomic.gff, organism: Mycoplasma suis KI3806
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_001484045.1_ASM148404v1/GCF_001484045.1_ASM148404v1_genomic.gff, organism: Mycoplasma sp. (ex Biomphalaria glabrata)
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000238995.1_ASM23899v1/GCF_000238995.1_ASM23899v1_genomic.gff, organism: Mycoplasma haemocanis str. Illinois
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000281235.1_ASM28123v1/GCF_000281235.1_ASM28123v1_genomic.gff, organism: Candidatus Mycoplasma haemolamae str. Purdue
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000477415.1_ASM47741v1/GCF_000477415.1_ASM47741v1_genomic.gff, organism: Mycoplasma parvum str. Indiana
# MISSED deoxyribose-phosphate aldolase in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000508245.1_ASM50824v1/GCF_000508245.1_ASM50824v1_genomic.gff, organism: Mycoplasma ovis str. Michigan
# 89 uniq prots in deoxyribose-phosphate aldolase
# 88 prots added to multifasta /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/deoxyribose-phosphate_aldolase.fasta
# take methyltransferase RsmH to build multifasta
# MISSED methyltransferase RsmH in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000013425.1/genomic.gff, organism: Staphylococcus aureus subsp. aureus NCTC 8325
# MISSED methyltransferase RsmH in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000009045.1/genomic.gff, organism: Bacillus subtilis subsp. subtilis str. 168
# MISSED methyltransferase RsmH in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000006945.2/genomic.gff, organism: Salmonella enterica subsp. enterica serovar Typhimurium str. LT2
# MISSED methyltransferase RsmH in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_003697165.1/genomic.gff, organism: Escherichia coli DSM 30083 = JCM 1649 = ATCC 11775
# 108 uniq prots in methyltransferase RsmH
# 106 prots added to multifasta /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/methyltransferase_RsmH.fasta
# take 50S ribosomal protein L32 to build multifasta
# MISSED 50S ribosomal protein L32 in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000013425.1/genomic.gff, organism: Staphylococcus aureus subsp. aureus NCTC 8325
# MISSED 50S ribosomal protein L32 in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000009045.1/genomic.gff, organism: Bacillus subtilis subsp. subtilis str. 168
# MISSED 50S ribosomal protein L32 in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000200735.1_ASM20073v1/GCF_000200735.1_ASM20073v1_genomic.gff, organism: Mycoplasma haemofelis str. Langford 1
# MISSED 50S ribosomal protein L32 in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000238995.1_ASM23899v1/GCF_000238995.1_ASM23899v1_genomic.gff, organism: Mycoplasma haemocanis str. Illinois
# 71 uniq prots in 50S ribosomal protein L32
# 71 prots added to multifasta /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/50S_ribosomal_protein_L32.fasta
# take chromosomal replication initiator protein DnaA to build multifasta
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000013425.1/genomic.gff, organism: Staphylococcus aureus subsp. aureus NCTC 8325
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/bact_to_compare/GCF_000009045.1/genomic.gff, organism: Bacillus subtilis subsp. subtilis str. 168
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000277795.1_ASM27779v1/GCF_000277795.1_ASM27779v1_genomic.gff, organism: Mycoplasma wenyonii str. Massachusetts
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_004771095.1_ASM477109v1/GCF_004771095.1_ASM477109v1_genomic.gff, organism: Mycoplasma gallisepticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000179035.2_ASM17903v2/GCF_000179035.2_ASM17903v2_genomic.gff, organism: Mycoplasma suis str. Illinois
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_007859615.1_ASM785961v1/GCF_007859615.1_ASM785961v1_genomic.gff, organism: Mycoplasma anserisalpingitidis
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_021460055.1_ASM2146005v1/GCF_021460055.1_ASM2146005v1_genomic.gff, organism: Ureaplasma urealyticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000200735.1_ASM20073v1/GCF_000200735.1_ASM20073v1_genomic.gff, organism: Mycoplasma haemofelis str. Langford 1
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_014352955.1_ASM1435295v1/GCF_014352955.1_ASM1435295v1_genomic.gff, organism: Mycoplasma sp. Pen4
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_006716625.1_ASM671662v1/GCF_006716625.1_ASM671662v1_genomic.gff, organism: Ureaplasma urealyticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_007858515.1_ASM785851v1/GCF_007858515.1_ASM785851v1_genomic.gff, organism: Mycoplasma anserisalpingitidis
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_019720735.1_ASM1972073v1/GCF_019720735.1_ASM1972073v1_genomic.gff, organism: Mycoplasma sp. Ms02
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_008728895.1_ASM872889v1/GCF_008728895.1_ASM872889v1_genomic.gff, organism: Mycoplasma gallisepticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_008728935.1_ASM872893v1/GCF_008728935.1_ASM872893v1_genomic.gff, organism: Mycoplasma gallisepticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_020497635.1_ASM2049763v1/GCF_020497635.1_ASM2049763v1_genomic.gff, organism: Mycoplasma anserisalpingitidis
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000286695.1_ASM28669v1/GCF_000286695.1_ASM28669v1_genomic.gff, organism: Mycoplasma gallisepticum NC95_13295-2-2P
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_017654545.1_ASM1765454v1/GCF_017654545.1_ASM1765454v1_genomic.gff, organism: Mycoplasma gallisepticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_009792315.1_ASM979231v1/GCF_009792315.1_ASM979231v1_genomic.gff, organism: Mycoplasma sp. NEAQ87857
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_014068355.1_ASM1406835v1/GCF_014068355.1_ASM1406835v1_genomic.gff, organism: Mycoplasma tullyi
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_007858495.1_ASM785849v1/GCF_007858495.1_ASM785849v1_genomic.gff, organism: Mycoplasma anserisalpingitidis
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_900476085.1_50569_G01/GCF_900476085.1_50569_G01_genomic.gff, organism: Mycoplasma gallisepticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000211545.4_ASM21154v6/GCF_000211545.4_ASM21154v6_genomic.gff, organism: Mycoplasma gallisepticum S6
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_013348745.1_ASM1334874v1/GCF_013348745.1_ASM1334874v1_genomic.gff, organism: Mycoplasma sp. OR1901
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_020497585.1_ASM2049758v1/GCF_020497585.1_ASM2049758v1_genomic.gff, organism: Mycoplasma anserisalpingitidis
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_004771115.1_ASM477111v1/GCF_004771115.1_ASM477111v1_genomic.gff, organism: Mycoplasma gallisepticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000286775.1_ASM28677v1/GCF_000286775.1_ASM28677v1_genomic.gff, organism: Mycoplasma gallisepticum NC06_2006.080-5-2P
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000203215.1_ASM20321v1/GCF_000203215.1_ASM20321v1_genomic.gff, organism: Mycoplasma suis KI3806
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_001484045.1_ASM148404v1/GCF_001484045.1_ASM148404v1_genomic.gff, organism: Mycoplasma sp. (ex Biomphalaria glabrata)
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000286715.1_ASM28671v1/GCF_000286715.1_ASM28671v1_genomic.gff, organism: Mycoplasma gallisepticum NC96_1596-4-2P
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000238995.1_ASM23899v1/GCF_000238995.1_ASM23899v1_genomic.gff, organism: Mycoplasma haemocanis str. Illinois
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000286735.1_ASM28673v1/GCF_000286735.1_ASM28673v1_genomic.gff, organism: Mycoplasma gallisepticum NY01_2001.047-5-1P
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000281235.1_ASM28123v1/GCF_000281235.1_ASM28123v1_genomic.gff, organism: Candidatus Mycoplasma haemolamae str. Purdue
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000286675.1_ASM28667v1/GCF_000286675.1_ASM28667v1_genomic.gff, organism: Mycoplasma gallisepticum VA94_7994-1-7P
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000092585.1_ASM9258v1/GCF_000092585.1_ASM9258v1_genomic.gff, organism: Mycoplasma gallisepticum str. R(low)
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000477415.1_ASM47741v1/GCF_000477415.1_ASM47741v1_genomic.gff, organism: Mycoplasma parvum str. Indiana
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000025385.1_ASM2538v1/GCF_000025385.1_ASM2538v1_genomic.gff, organism: Mycoplasma gallisepticum str. F
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000508245.1_ASM50824v1/GCF_000508245.1_ASM50824v1_genomic.gff, organism: Mycoplasma ovis str. Michigan
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_019873825.1_ASM1987382v1/GCF_019873825.1_ASM1987382v1_genomic.gff, organism: Mycoplasma sp. E35C
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000286755.1_ASM28675v1/GCF_000286755.1_ASM28675v1_genomic.gff, organism: Mycoplasma gallisepticum WI01_2001.043-13-2P
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_006228185.1_ASM622818v1/GCF_006228185.1_ASM622818v1_genomic.gff, organism: Mycoplasma nasistruthionis
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_008728915.1_ASM872891v1/GCF_008728915.1_ASM872891v1_genomic.gff, organism: Mycoplasma gallisepticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_006777105.1_ASM677710v1/GCF_006777105.1_ASM677710v1_genomic.gff, organism: Ureaplasma urealyticum
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000286815.1_ASM28681v1/GCF_000286815.1_ASM28681v1_genomic.gff, organism: Mycoplasma gallisepticum NC08_2008.031-4-3P
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000025845.1_ASM2584v1/GCF_000025845.1_ASM2584v1_genomic.gff, organism: Mycoplasma crocodyli MP145
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000286795.1_ASM28679v1/GCF_000286795.1_ASM28679v1_genomic.gff, organism: Mycoplasma gallisepticum CA06_2006.052-5-2P
# MISSED chromosomal replication initiator protein DnaA in /home/dzilov/data_zilov/data/mycoplasma/all_complete_genomes/GCF_000025365.1_ASM2536v1/GCF_000025365.1_ASM2536v1_genomic.gff, organism: Mycoplasma gallisepticum str. R(high)
# 96 uniq prots in chromosomal replication initiator protein DnaA
# 95 prots added to multifasta /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/chromosomal_replication_initiator_protein_DnaA.fasta

# %%
## MSA with MUSCLE for each protein cluster

#write commands for xargs

muscle_xargs = '/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/xargs_muscle.txt'
muscle_dir = '/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/muscle'

multifasta_list = glob('/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/*.fasta')


with open(muscle_xargs, 'w') as fw:
    for i in multifasta_list:
        out = os.path.join(muscle_dir, f"alignment_{os.path.basename(i)}")
        fw.write(f'/home/dzilov/soft/miniconda3/envs/muscle/bin/muscle -in {i} -out {out}\n')

command = "less /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/xargs_muscle.txt | xargs -I {} -P 15 sh -c '{}'"
os.system(command)

# %%
## phylogeny with IQTree for each protein cluster alignment

#write commands for xargs

iqtree_xargs = '/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/xargs_iqtree.txt'
iqtree_dir = '/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/iqtree_with_acholeplasma/'

alignment_list = glob('/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/muscle/*.fasta')

with open(iqtree_xargs, 'w') as fw:
    for i in alignment_list:
        out = os.path.join(iqtree_dir, os.path.splitext(os.path.basename(i))[0])
        fw.write(f'/home/dzilov/soft/miniconda3/envs/iqtree/bin/iqtree -T 1 --mem 100G -s {i} --prefix {out}\n')
        
command = "less /home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/xargs_iqtree.txt | xargs -I {} -P 15 sh -c '{}'"
os.system(command)

# %%
## tree to png

## conda activate newick_utils

tree_draw_xargs = '/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/xargs_drawtree.txt'
pic_dir = '/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/iqtree_new/tree_pics/'

trees = glob('/home/dzilov/data_zilov/data/mycoplasma/clusters/multifasta/iqtree_w/*.treefile')

with open(tree_draw_xargs, 'w') as fw:
    for tree in trees:
        print(tree)
        prot_name = os.path.basename(tree).split('.treefile')[0]
        fw.write(f'nw_display -w 2000 -s {tree} > {pic_dir}{prot_name}.svg\n')
        fw.write(f'convert {pic_dir}{prot_name}.svg {pic_dir}{prot_name}.png\n')
        fw.write(f'rm {pic_dir}{prot_name}.svg\n')

# %%
summary_file = '/media/eternus1/projects/zilov/data/mycoplasma/clusters/multifasta/mycoplasma_targets_to_tree_summary.tsv'

with open(summary_file, "w") as fw:
    fw.write('#target\tgenomes_analyzed\tmissed_genomes\tunique_sequnces\tmultifasta_file\n')
    for cl in summary_table:
        line_to_write = "\t".join(cl)
        fw.write(f'{line_to_write}\n')

# %%
summary_table

# %%
consensus_table = defaultdict()

for v in fasta_msa.values():
    for i in range(len(v)):
        consensus_table[i] = {'A': 0, 'C': 0, 'G': 0, 'T': 0, '-': 0, 'N': 0}
    break

for k, v in fasta_msa.items():
    for i, n in enumerate(v):
        consensus_table[i][n] += 1

# %%
consensus = []

for k, v in consensus_table.items():
    few_n = []
    
    for n, c in v.items():
        if c == len(fasta_msa):
            few_n.append(n)
        else:
            if c != 0:
                if c / len(fasta_msa) > .3:
                    few_n.append(n)
      
    if len(few_n) == 1:
        if '-' in few_n:
            consensus.append('N')
        else:
            consensus.append(few_n[0])
    elif ('A' in few_n and 'T' in few_n and 'G' in few_n and 'C' in few_n) or ('-' in few_n):
        consensus.append('N')
    elif 'A' in few_n and 'G' in few_n:
        if 'C' in few_n:
            consensus.append('V')
        elif 'T' in few_n:
            consensus.append('D')
        else:
            consensus.append('R')
    elif 'A' in few_n and 'T' in few_n:
        if 'C' in few_n:
            consensus.append('H')
        else:
            consensus.append('W')
    elif 'G' in few_n and 'C' in few_n:
        if 'T' in few_n:
            consensus.append('B')
        else:
            consensus.append('S')
    elif 'G' in few_n and 'T' in few_n:
        consensus.append('K')
    elif 'C' in few_n and 'T' in few_n:
        consensus.append('Y')
    elif 'A' in few_n and 'C' in few_n:
        consensus.append('M')
        
    return ''.join(consensus)
